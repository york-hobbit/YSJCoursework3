# %%
#The data was accessed from Kaggle ast https://www.kaggle.com/datasets/Cornell-University/arxiv
#and the 5 columns of interest were used to create a new dataset

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
#Read csv myscvfile
df = pd.read_csv('mycsvfile.csv',  dtype='unicode')

# %%
#Check first 10 entries
df.head(10)
# Out:
#           id                                              title  \
# 0  0704.0001  Calculation of prompt diphoton production cros...
# 1  0704.0002           Sparsity-certifying Graph Decompositions
# 2  0704.0003  The evolution of the Earth-Moon system based o...
# 3  0704.0004  A determinant of Stirling cycle numbers counts...
# 4  0704.0006  Bosonic characters of atomic Cooper pairs acro...
# 5  0704.0007  Polymer Quantum Mechanics and its Continuum Limit
# 6  0704.0008  Numerical solution of shock and ramp compressi...
# 7  0704.0010  Partial cubes: structures, characterizations, ...
# 8  0704.0011  Computing genus 2 Hilbert-Siegel modular forms...
# 9  0704.0014             Iterated integral and the loop product
#
#                                             comments  \
# 0            37 pages, 15 figures; published version
# 1              To appear in Graphs and Combinatorics
# 2                                23 pages, 3 figures
# 3                                           11 pages
# 4                6 pages, 4 figures, accepted by PRA
# 5  16 pages, no figures. Typos corrected to match...
# 6                                  Minor corrections
# 7                               36 pages, 17 figures
# 8  14 pages; title changed; to appear in Experime...
# 9                                 18 pages, 1 figure
#
#                                          journal-ref         categories
# 0                           Phys.Rev.D76:013009,2007             hep-ph
# 1                                                NaN      math.CO cs.CG
# 2                                                NaN     physics.gen-ph
# 3                                                NaN            math.CO
# 4                                                NaN  cond-mat.mes-hall
# 5                           Phys.Rev.D76:044016,2007              gr-qc
# 6  Journal of Applied Physics, vol 104, 073536 (2...  cond-mat.mtrl-sci
# 7                                                NaN            math.CO
# 8                                                NaN    math.NT math.AG
# 9                                                NaN    math.CA math.AT

# %%
# Check last 10 entries
df.tail(10)
# Out:
#                        id                                              title  \
# 1726201  supr-con/9608003  Extended bound states and resonances of two fe...
# 1726202  supr-con/9608004  Ginzburg-Landau-Gor'kov Theory of Magnetic osc...
# 1726203  supr-con/9608005  Evidence for Quasiparticle Decay in Photoemiss...
# 1726204  supr-con/9608006  Strong coupling theory of the interlayer tunne...
# 1726205  supr-con/9608007  The Fluctuation Induced Pseudogap in the Infra...
# 1726206  supr-con/9608008  On the origin of the irreversibility line in t...
# 1726207  supr-con/9609001  Nonlinear Response of HTSC Thin Film Microwave...
# 1726208  supr-con/9609002  Critical State Flux Penetration and Linear Mic...
# 1726209  supr-con/9609003  Density of States and NMR Relaxation Rate in A...
# 1726210  supr-con/9609004  Ginzburg Landau theory for d-wave pairing and ...
#
#                                                   comments  \
# 1726201  21 pages, RevTeX, 4 Postscript figures, arithm...
# 1726202  39 pages, 8 figures. This is a replacement of ...
# 1726203                   4 pages of ReVTeX, 3 eps figures
# 1726204  23 pages, 7 Postscript figures, REVTeX 3.0 wit...
# 1726205  8 pages, 4 eps figures, Submitted to Phys. Rev. B
# 1726206  19 pages, LaTex, 6 PostScript figures; Author'...
# 1726207  4 pages, LaTeX type, Uses IEEE style files, 60...
# 1726208  20 pages, LaTeX type, Uses REVTeX style files,...
# 1726209  7 pages, 4 PostScript Figures, LaTeX, to appea...
# 1726210  12 pages including 8 eps figs, LaTeX with jpsj...
#
#                                    journal-ref                  categories
# 1726201           Phys. Rev. B 55, 6035 (1997)  supr-con cond-mat.supr-con
# 1726202  PHYS REV B 56: (2) 809-825 JUL 1 1997  supr-con cond-mat.supr-con
# 1726203       Phys. Rev. Lett. 79, 1726 (1997)  supr-con cond-mat.supr-con
# 1726204                                    NaN  supr-con cond-mat.supr-con
# 1726205                                    NaN  supr-con cond-mat.supr-con
# 1726206                                    NaN  supr-con cond-mat.supr-con
# 1726207                                    NaN  supr-con cond-mat.supr-con
# 1726208                                    NaN  supr-con cond-mat.supr-con
# 1726209                                    NaN  supr-con cond-mat.supr-con
# 1726210     J. Phys. Soc. Jpn. 66, 204 (1997).  supr-con cond-mat.supr-con

# %%
#Information on dataset, number of rows, columns and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1726211 entries, 0 to 1726210
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           object
#  1   title        object
#  2   comments     object
#  3   journal-ref  object
#  4   categories   object
# dtypes: object(5)
# memory usage: 65.8+ MB

# %%
#Dataset description 
df.describe(include='all')
# Out:
#                id                                              title  \
# count     1726211                                            1726211
# unique    1726211                                            1722861
# top     0704.0001  Discussion of: A statistical analysis of multi...
# freq            1                                                 12
#
#         comments                                        journal-ref categories
# count    1726178                                             680809    1726211
# unique   1063653                                             676223      63073
# top     10 pages  Dans Design, Automation and Test in Europe - D...   astro-ph
# freq        7551                                                127      85695

# %%
#Check for null values, comments field should have no null values as theses should have been removed when the dataset was
#extracted from kaggle.
df.isnull().sum()
# Out:
# id                   0
# title                0
# comments            33
# journal-ref    1045402
# categories           0
# dtype: int64

# %%
#Find rows with null data values
df[df['comments'].isna()]
# Out:
#                  id                                              title  \
# 82050     0811.2543  A Non-Renormalized Field Theoretic Treatment o...
# 96428     0902.4400  The Relativistic Electrodynamics Least Action ...
# 366713    1306.5516  Some Generalization of Hadamard's type Inequal...
# 529770   1508.05368  Quaternion Generalization of Super Poincare Group
# 734968   1801.04866  An inverse problem for the relativistic Schr\"...
# 839001   1902.02144  Progressive Generative Adversarial Networks fo...
# 849973   1903.07034  Reconstruction for the coefficients of a quasi...
# 884695   1907.06086  Skew Generalized Cyclic Code over $\n  R[x_1;\...
# 896372   1908.09281  Quantum Brayton Engine of Non-Interacting Ferm...
# 982700   2006.01381              Identifying Fake Profiles in LinkedIn
# 1026195  2010.05018  Inequalities for Taylor series involving the d...
# 1032102  2010.13852  A State-of-the-Art Review on IoT botnet Attack...
# 1034328  2011.00772  Some extended hypergeometric matrix functions ...
# 1054668  2101.00527  Statistical Inference on the Hilbert Sphere wi...
# 1059604  2101.08104       A Generalized Weisfeiler-Lehman Graph Kernel
# 1066807  2102.06364  Software Estimations Risk in Pakistan Software...
# 1070890  2102.12754  An isotropic compact stellar model in curvatur...
# 1071329  2102.13489  Pulsar PSR B0943+10 as an isotropic Vaidya-Tik...
# 1077523  2103.09396  Pros and Cons of GAN Evaluation Measures: New ...
# 1127997  2108.06906  Micro-structural characteristics and indentati...
# 1140894  2109.11896  A Model-Driven Approach to Reengineering Proce...
# 1141247  2109.12442  Unblind the charts: Towards Making Interactive...
# 1176441  2201.03052  Measuring User Perceived Security of Mobile Ba...
# 1187458  2202.06900  Hydrothermal synthesis, structure, and antibac...
# 1212077  2204.13312  Observation of intrinsic crystal phase in bare...
# 1212082  2204.13318  Multi-wavelength magnetic coding of helical lu...
# 1237212  2207.06621  NaCo2(SeO3)2(OH): Competing Magnetic Ground St...
# 1269165  2210.10901  Modeling Reactive Hyperemia to better understa...
# 1270540  2210.12964  Non-Contrastive Learning-based Behavioural Bio...
# 1297930  2301.06718  Sparse and Integrative Principal Component Ana...
# 1320513  2303.15530  A New Index based on Power Splitting Indices f...
# 1327355  2304.08597  eTOP: Early Termination of Pipelines for Faste...
# 1335288  2305.06882           Evidence of Space weather in Radon Decay
#
#         comments                                        journal-ref  \
# 82050        NaN                                                NaN
# 96428        NaN                                                NaN
# 366713       NaN  Indian Journal 0f Pure Applied Mathematics, 44...
# 529770       NaN                                                NaN
# 734968       NaN                          Applicable Analysis, 2019
# 839001       NaN                                                NaN
# 849973       NaN                   Applied Mathematics Letters-2019
# 884695       NaN                                                NaN
# 896372       NaN                                                NaN
# 982700       NaN                                                NaN
# 1026195      NaN                                                NaN
# 1032102      NaN                                                NaN
# 1034328      NaN                                                NaN
# 1054668      NaN                                                NaN
# 1059604      NaN                                                NaN
# 1066807      NaN                                                NaN
# 1070890      NaN                                                NaN
# 1071329      NaN                                                NaN
# 1077523      NaN                                                NaN
# 1127997      NaN                                                NaN
# 1140894      NaN                                                NaN
# 1141247      NaN                                                NaN
# 1176441      NaN                                                NaN
# 1187458      NaN                                                NaN
# 1212077      NaN                 Nanophotonics, 2022, 11, 4409-4417
# 1212082      NaN                                                NaN
# 1237212      NaN                                                NaN
# 1269165      NaN              Annals of Biomedical Engineering 2023
# 1270540      NaN                                                NaN
# 1297930      NaN                                                NaN
# 1320513      NaN                                                NaN
# 1327355      NaN                                                NaN
# 1335288      NaN                                                NaN
#
#                                           categories
# 82050                                       quant-ph
# 96428                                math-ph math.MP
# 366713                               math.FA math.CA
# 529770                                physics.gen-ph
# 734968                                       math.AP
# 839001                                         cs.CV
# 849973                                       math.AP
# 884695                                 cs.IT math.IT
# 896372                            cond-mat.stat-mech
# 982700                             cs.SI cs.CY cs.LG
# 1026195                              math.NT math.CA
# 1032102                                        cs.NI
# 1034328                                      math.CA
# 1054668                      math.ST stat.ME stat.TH
# 1059604                                        cs.LG
# 1066807                                        cs.SE
# 1070890                                  astro-ph.GA
# 1071329                            gr-qc astro-ph.HE
# 1077523                            cs.LG cs.AI cs.CV
# 1127997            cond-mat.mtrl-sci cond-mat.dis-nn
# 1140894                                        cs.SE
# 1141247                                  cs.HC cs.SE
# 1176441                            cs.HC cs.CR cs.CY
# 1187458                               physics.app-ph
# 1212077                            cond-mat.mtrl-sci
# 1212082                            cond-mat.mtrl-sci
# 1237212            cond-mat.str-el cond-mat.mtrl-sci
# 1269165                                     q-bio.TO
# 1270540                            cs.CR cs.AI cs.LG
# 1297930                                      stat.ME
# 1320513                                eess.SY cs.SY
# 1327355                                  cs.LG cs.IR
# 1335288  hep-ex astro-ph.GA nucl-ex physics.space-ph

# %%
#Drop rows with NaN in comments and check to see if they have been removed (original method did not remove the NaN values)
df = df[df['comments'].notna()]
df.isnull().sum()
# Out:
# id                   0
# title                0
# comments             0
# journal-ref    1045374
# categories           0
# dtype: int64

# %%
#Check to see if None is present in the comments field
check_1 = df[df['comments'].str.contains('None')]
print(check_1)
# Out:
# Empty DataFrame
# Columns: [id, title, comments, journal-ref, categories]
# Index: []

# %%
#Check title for COVID, covid or Covid
check_2 = df[df['title'].str.contains('COVID|Covid|covid')]
print(check_2)
# Out:
# Empty DataFrame
# Columns: [id, title, comments, journal-ref, categories]
# Index: []

# %%
#Check duplicate rows title
duplicate = df[df.duplicated('title')]

duplicate.shape
# Out:
# (3350, 5)

# %%
duplicate.head(30)
# Out:
#               id                                              title  \
# 15821  0708.0098  Discussion of ``2004 IMS Medallion Lecture: Lo...
# 15843  0708.0121  Discussion of ``2004 IMS Medallion Lecture: Lo...
# 15846  0708.0124  Discussion of ``2004 IMS Medallion Lecture: Lo...
# 15852  0708.0132  Discussion of ``2004 IMS Medallion Lecture: Lo...
# 15984  0708.0287  Comment: Expert Elicitation for Reliable Syste...
# 15985  0708.0288  Comment: Expert Elicitation for Reliable Syste...
# 16030  0708.0336  Comment: Monitoring Networked Applications Wit...
# 16032  0708.0338  Comment: Monitoring Networked Applications Wit...
# 17854  0708.2385  A centimetre-wave excess over free-free emissi...
# 19091  0708.3777  Comment: Fisher Lecture: Dimension Reduction i...
# 19093  0708.3779  Comment: Fisher Lecture: Dimension Reduction i...
# 22501  0709.3214  Hard spectator interactions in B to pi pi at o...
# 23050  0709.3834  Back-in-time dynamics of the cluster IE 0657-5...
# 25643  0710.2085  Screening masses in the SU(3) pure gauge theor...
# 26388  0710.2925  Bridging over p-wave pi-production and weak pr...
# 26404  0710.2942     Rapidity gap survival in the black-disk regime
# 28261  0710.5012  Comment: Struggles with Survey Weighting and R...
# 28262  0710.5013  Comment: Struggles with Survey Weighting and R...
# 28264  0710.5015  Comment: Struggles with Survey Weighting and R...
# 28265  0710.5016  Comment: Struggles with Survey Weighting and R...
# 30766  0711.1925      Phase structure of twisted Eguchi-Kawai model
# 30995  0711.2189  Search for Lepton Flavor Violating tau Decays ...
# 32778  0711.4241  Radial Dependence of Extinction in Parent Gala...
# 33062  0711.4557  On Outage Behavior of Wideband Slow-Fading Cha...
# 34008  0712.0634  High-precision covariant one-boson-exchange po...
# 34131  0712.0772  3D SPH simulations of grain growth in protopla...
# 36042  0712.2964  Gamma-Ray Emission from PWNe Interacting with ...
# 36489  0712.3493       Measurement of the Decay B- --> D*0 e- nubar
# 37294  0712.4391  The formation of spiral arms and rings in barr...
# 37642  0801.0366  The formation of spiral arms and rings in barr...
#
#                                                 comments  \
# 15821  Published at http://dx.doi.org/10.1214/0090536...
# 15843  Published at http://dx.doi.org/10.1214/0090536...
# 15846  Published at http://dx.doi.org/10.1214/0090536...
# 15852  Published at http://dx.doi.org/10.1214/0090536...
# 15984  Published at http://dx.doi.org/10.1214/0883423...
# 15985  Published at http://dx.doi.org/10.1214/0883423...
# 16030  Published at http://dx.doi.org/10.1214/0883423...
# 16032  Published at http://dx.doi.org/10.1214/0883423...
# 17854  accepted for publication in MNRAS; corrected t...
# 19091  Published at http://dx.doi.org/10.1214/0883423...
# 19093  Published at http://dx.doi.org/10.1214/0883423...
# 22501  Publication based on my PhD thesis, 41 pages, ...
# 23050             This is a duplicate of arXiv:0709.3572
# 25643  7 pages, presented at the XXV International Sy...
# 26388  5 pages, 2 figures, Contribution to proceeding...
# 26404  9 pages, 4 figures, To appear in the proceedin...
# 28261  Published in at http://dx.doi.org/10.1214/0883...
# 28262  Published in at http://dx.doi.org/10.1214/0883...
# 28264  Published in at http://dx.doi.org/10.1214/0883...
# 28265  Published in at http://dx.doi.org/10.1214/0883...
# 30766              17 pages, 7 figures, minor correction
# 30995    11 pages, 4 figures, submitted to Phys. Lett. B
# 32778  Accepted for publication in RevMexAA, 10 pages...
# 33062  Submitted to IEEE Transactions on Information ...
# 34008  3 pages, 1 figure. To appear in the proceeding...
# 34131  3 pages, 3 figures, to appear in the Proceedin...
# 36042                  accepted for publication in MNRAS
# 36489  version 1: 8 pages, 1 postscript figure, submi...
# 37294  9 pages, 4 figures, conference proceedings of ...
# 37642  6 pages, 3 figures, conference proceedings of ...
#
#                                              journal-ref  \
# 15821  Annals of Statistics 2006, Vol. 34, No. 6, 267...
# 15843  Annals of Statistics 2006, Vol. 34, No. 6, 267...
# 15846  Annals of Statistics 2006, Vol. 34, No. 6, 268...
# 15852  Annals of Statistics 2006, Vol. 34, No. 6, 268...
# 15984  Statistical Science 2006, Vol. 21, No. 4, 454-455
# 15985  Statistical Science 2006, Vol. 21, No. 4, 456-459
# 16030  Statistical Science 2006, Vol. 21, No. 4, 479-482
# 16032  Statistical Science 2006, Vol. 21, No. 4, 483-484
# 17854                                                NaN
# 19091    Statistical Science 2007, Vol. 22, No. 1, 32-35
# 19093    Statistical Science 2007, Vol. 22, No. 1, 36-39
# 22501                        Nucl.Phys.B794:154-188,2008
# 23050                                                NaN
# 25643                                PoSLAT2007:183,2007
# 26388                              ECONFC070910:264,2007
# 26404                                                NaN
# 28261  Statistical Science 2007, Vol. 22, No. 2, 168-170
# 28262  Statistical Science 2007, Vol. 22, No. 2, 171-174
# 28264  Statistical Science 2007, Vol. 22, No. 2, 175-178
# 28265  Statistical Science 2007, Vol. 22, No. 2, 179-183
# 30766                                  JHEP0801:025,2008
# 30995                        Phys.Lett.B660:154-160,2008
# 32778  Revista Mexicana de Astronomia y Astrofisica V...
# 33062                                                NaN
# 34008                      Few Body Syst.44:295-298,2008
# 34131  Dans Proceedings of IAU Symp. 249 - Exoplanets...
# 36042                                                NaN
# 36489                      Phys.Rev.Lett.100:231803,2008
# 37294                                                NaN
# 37642                                                NaN
#
#                      categories
# 15821  q-fin.RM math.ST stat.TH
# 15843  q-fin.RM math.ST stat.TH
# 15846  q-fin.RM math.ST stat.TH
# 15852  q-fin.RM math.ST stat.TH
# 15984                   stat.ME
# 15985                   stat.ME
# 16030                   stat.ME
# 16032                   stat.ME
# 17854                  astro-ph
# 19091                   stat.ME
# 19093                   stat.ME
# 22501                    hep-ph
# 23050                  astro-ph
# 25643                   hep-lat
# 26388            nucl-th hep-ph
# 26404                    hep-ph
# 28261                   stat.ME
# 28262                   stat.ME
# 28264                   stat.ME
# 28265                   stat.ME
# 30766            hep-lat hep-th
# 30995                    hep-ex
# 32778                  astro-ph
# 33062             cs.IT math.IT
# 34008                   nucl-th
# 34131                  astro-ph
# 36042                  astro-ph
# 36489                    hep-ex
# 37294                  astro-ph
# 37642                  astro-ph

# %%
# Check duplicates title, journal-ref, catagories
duplicate_ref = df[df.duplicated(['title', 'journal-ref', 'categories'])]

duplicate_ref.shape
# Out:
# (810, 5)

# %%
duplicate_ref.head(30)
# Out:
#                id                                              title  \
# 17854   0708.2385  A centimetre-wave excess over free-free emissi...
# 23050   0709.3834  Back-in-time dynamics of the cluster IE 0657-5...
# 26404   0710.2942     Rapidity gap survival in the black-disk regime
# 33062   0711.4557  On Outage Behavior of Wideband Slow-Fading Cha...
# 37294   0712.4391  The formation of spiral arms and rings in barr...
# 37642   0801.0366  The formation of spiral arms and rings in barr...
# 39864   0801.2933  Structure and Evolution of the Opacity of Spir...
# 39869   0801.2938                  Spitzer's View of Edge-on Spirals
# 42923   0802.1543    Tidal Evolution of Close-in Extra-Solar Planets
# 54746   0805.1442  How Many Users should be Turned On in a Multi-...
# 59914   0806.2522             Supersymmetry Searches at the Tevatron
# 60941   0806.3698                       Scalar Meson Photoproduction
# 70198   0808.4101  Are ring galaxies the ancestors of giant low s...
# 71709   0809.1668        On the nature of Delta Scuti star HD 115520
# 74971   0810.0166  Pulsating B and Be stars in the Magellanic Clouds
# 75403   0810.0655  High-statistics measurement of neutral-pion pa...
# 83901   0811.4682  Precision Electroweak Measurements and Constra...
# 88857   0901.0521           On Multipath Fading Channels at High SNR
# 93831   0902.1314  New magnetic field measurements of beta Cephei...
# 98212   0903.1588  On the Growth Rate of the Weight Distribution ...
# 98404   0903.1820  On the Capacity of Free-Space Optical Intensit...
# 98997   0903.2503  Combination of CDF and D0 Results on the Mass ...
# 107438  0905.2026  Determination of the 3He+alpha\to 7Be asymp. n...
# 116784  0907.2386  Discovery of Very High Energy gamma-rays from ...
# 121638  0908.2382                             Direct Photons at RHIC
# 125241  0909.1950  EAGLE Spectroscopy of Resolved Stellar Populat...
# 130615  0910.2545    Primordial Binary Evolution and Blue Stragglers
# 131137  0910.3160  The Final Measurement of Epsilon'/Epsilon from...
# 132855  0910.5156  Alignment of the ATLAS Inner Detector Tracking...
# 135718  0911.2604  Precision Electroweak Measurements and Constra...
#
#                                                  comments  \
# 17854   accepted for publication in MNRAS; corrected t...
# 23050              This is a duplicate of arXiv:0709.3572
# 26404   9 pages, 4 figures, To appear in the proceedin...
# 33062   Submitted to IEEE Transactions on Information ...
# 37294   9 pages, 4 figures, conference proceedings of ...
# 37642   6 pages, 3 figures, conference proceedings of ...
# 39864   8 pages, 4 figures, to appear in the proceedin...
# 39869   4 pages, 4 figures, to appear in the proceedin...
# 42923   9 pages, 3 figures. To appear in the proceedin...
# 54746   IEEE JSAC Special Issue on Exploiting Limited ...
# 59914   4 pages, 6 figures, Proceedings of the XLIII R...
# 60941                      32 pages, 11 figures, 7 tables
# 70198   5 pages, 3 figures, to appear in "The Galaxy D...
# 71709   6 pages. To be published in Journal of Physics...
# 74971   4 pages, 1 figure, contributed poster to the V...
# 75403   3 pages, 4 figures, proceedings to poster sess...
# 83901                                            18 pages
# 88857   Submitted to the IEEE Transactions on Informat...
# 93831   13 pages, 10 figures, 4 tables, accepted for p...
# 98212   Revision of the journal paper. 37 pages, 2 fig...
# 98404   Transmitted to IEEE Transactions on Informatio...
# 98997   FERMILAB-TM-2427-E, TEVEWWG/top 2009/03, CDF N...
# 107438                      24 pages, 5 figures, 2 tables
# 116784                                   accepted to ApJL
# 121638  7 pages, 5 figures, to appear in the proceedin...
# 125241  4 pages, to appear in the proceedings of IAU S...
# 130615                              Oral talk on IAUS 266
# 131137  10 pages, 19 figures. To be published in the p...
# 132855  To be published in the proceedings of DPF-2009...
# 135718                                           18 pages
#
#                      journal-ref               categories
# 17854                        NaN                 astro-ph
# 23050                        NaN                 astro-ph
# 26404                        NaN                   hep-ph
# 33062                        NaN            cs.IT math.IT
# 37294                        NaN                 astro-ph
# 37642                        NaN                 astro-ph
# 39864                        NaN                 astro-ph
# 39869                        NaN                 astro-ph
# 42923                        NaN                 astro-ph
# 54746                        NaN            cs.IT math.IT
# 59914                        NaN                   hep-ex
# 60941                        NaN                   hep-ph
# 70198                        NaN                 astro-ph
# 71709                        NaN                 astro-ph
# 74971                        NaN                 astro-ph
# 75403   Phys.Rev.D78:052004,2008                   hep-ex
# 83901                        NaN                   hep-ex
# 88857                        NaN            cs.IT math.IT
# 93831                        NaN              astro-ph.SR
# 98212                        NaN            cs.IT math.IT
# 98404                        NaN            cs.IT math.IT
# 98997                        NaN                   hep-ex
# 107438                       NaN                  nucl-th
# 116784                       NaN              astro-ph.CO
# 121638                       NaN                  nucl-ex
# 125241                       NaN  astro-ph.IM astro-ph.CO
# 130615                       NaN              astro-ph.SR
# 131137                       NaN                   hep-ex
# 132855                       NaN   physics.ins-det hep-ex
# 135718                       NaN                   hep-ex

# %%
# Check duplicates title, journal-ref, comments
duplicate_ref_com = df[df.duplicated(['title', 'journal-ref', 'comments'])]

duplicate_ref_com.shape
# Out:
# (29, 5)

# %%
duplicate_ref_com.head(30)
# Out:
#                        id                                              title  \
# 135718          0911.2604  Precision Electroweak Measurements and Constra...
# 146842          1001.4548                               On the BICM Capacity
# 147327          1001.5100  On Exponential Sums, Nowton identities and Dic...
# 153050          1003.1370  AKARI's infrared view on nearby stars : Using ...
# 161313          1004.5254  D\'eveloppements asymptotiques combin\'es et p...
# 164220          1005.3192  Associative Geometries. I: Torsors, linear rel...
# 164221          1005.3193  Associative Geometries. II: Involutions, the c...
# 182970          1009.3141  Analysis of semidiscretization of the compress...
# 198425          1012.2367  Precision Electroweak Measurements and Constra...
# 370771          1307.3655         Photoionization Delay in He, Ne, Ar and Kr
# 450079          1408.2053  Predicting the behavior of interacting humans ...
# 450090          1408.2065                         Normalized Online Learning
# 568882         1602.03863  Resolving the problem of definite outcomes of ...
# 634649         1611.08373  Bidirectional LSTM-CRF for Clinical Concept Ex...
# 967191         2004.07927  Primordial plasma: influence of non-ideality o...
# 1397635  astro-ph/9506093                     The environments of z<0.3 QSOs
# 1450510  cond-mat/0409276                      This paper has been withdrawn
# 1464362  cond-mat/0605616  Pi-Josephson Junction and Spontaneous Superflo...
# 1472169  cond-mat/9312022                   Self-Similarity of Friction Laws
# 1487039  cond-mat/9904049                                          withdrawn
# 1502719     gr-qc/0402014  Regularization parameters for the self-force o...
# 1508759     gr-qc/9409025  The Bianchi Ix (MIXMASTER) Cosmological Model ...
# 1520691    hep-ex/9902018  Study of the Photonuclear interaction of muons...
# 1525282   hep-lat/9204015  Blockspin Cluster Algorithms for Quantum Spin ...
# 1571290    hep-ph/9708268  Two-Body Dirac Equation and Its Wave Function ...
# 1642173      math/0401285  A discrete form of the theorem that each field...
# 1683851   nucl-th/9310016  Alpha Clustering and the stellar nucleosynthes...
# 1683852   nucl-th/9310017  Properties of $^{8}$Be and $^{12}$C deduced fr...
# 1684017   nucl-th/9404022        Direct mechanism in solar nuclear reactions
#
#                                                   comments  \
# 135718                                            18 pages
# 146842   Submitted to the IEEE Transactions on Informat...
# 147327                                            18 pages
# 153050   14 pages, 11 figures, accepted for publication...
# 161313   141 pages num\'erot\'ees par paires de 1 \`a 7...
# 164220   v2: new results on relation with lattice theor...
# 164221   V2: terminology changed ("torsor" instead of "...
# 182970                                            31 pages
# 198425                                            18 pages
# 370771   This paper has been withdrawn by the author be...
# 450079   Appears in Proceedings of the Twenty-Eighth Co...
# 450090   Appears in Proceedings of the Twenty-Ninth Con...
# 568882   superseded by arXiv:2002.11170 "Entanglement a...
# 634649   This paper "Bidirectional LSTM-CRF for Clinica...
# 967191                                  7 pages, 2 figures
# 1397635  uuencoded compressed postscript. The preprint ...
# 1450510                      This paper has been withdrawn
# 1464362  6 pages, 3 figures, Introduction and List of R...
# 1472169                    Plain TEX. Figures not included
# 1487039                                          withdrawn
# 1502719                                27 pages, no figure
# 1508759                               14 pages, no figures
# 1520691  4 pages, 2 figures, to be published in Proc. o...
# 1525282                                           11 pages
# 1571290                                    LaTeX, 12 pages
# 1642173  to appear in Aequationes Math., Theorem 5 prov...
# 1683851                                      2 pages LaTeX
# 1683852  2 pages LaTeX, 2 figures can be obtained from ...
# 1684017  17 pages, LaTeX, 5 figures available upon requ...
#
#                                                journal-ref  \
# 135718                                                 NaN
# 146842   IEEE Trans. Inform. Theory, vol. 57, no. 10, p...
# 147327                                                 NaN
# 153050                                                 NaN
# 161313                                                 NaN
# 164220                                                 NaN
# 164221                                                 NaN
# 182970                                                 NaN
# 198425                                                 NaN
# 370771                                                 NaN
# 450079                                                 NaN
# 450090                                                 NaN
# 568882                                                 NaN
# 634649                                                 NaN
# 967191                                                 NaN
# 1397635                                                NaN
# 1450510                                                NaN
# 1464362                                                NaN
# 1472169                                                NaN
# 1487039                                                NaN
# 1502719                                                NaN
# 1508759                                                NaN
# 1520691                                                NaN
# 1525282                                                NaN
# 1571290                                                NaN
# 1642173  Aequationes Mathematicae 71 (2006), no. 1-2, p...
# 1683851                                                NaN
# 1683852                                                NaN
# 1684017                                                NaN
#
#                               categories
# 135718                            hep-ex
# 146842                     cs.IT math.IT
# 147327                     cs.IT math.IT
# 153050                       astro-ph.SR
# 161313                           math.DS
# 164220                           math.RA
# 164221                           math.RA
# 182970                           math.CA
# 198425                            hep-ex
# 370771                   physics.atom-ph
# 450079                             cs.AI
# 450090                     cs.LG stat.ML
# 568882                          quant-ph
# 634649               stat.ML cs.CL cs.LG
# 967191   physics.plasm-ph physics.gen-ph
# 1397635                         astro-ph
# 1450510                  cond-mat.dis-nn
# 1464362  cond-mat.supr-con cond-mat.soft
# 1472169                         cond-mat
# 1487039                  cond-mat.str-el
# 1502719                            gr-qc
# 1508759                            gr-qc
# 1520691                           hep-ex
# 1525282                          hep-lat
# 1571290                           hep-ph
# 1642173                  math.NT math.AC
# 1683851                          nucl-th
# 1683852                          nucl-th
# 1684017                          nucl-th

# %%
# Check duplicates title, journal-ref, comments
duplicate_all= df[df.duplicated(['title', 'journal-ref', 'comments', 'categories'])]

duplicate_all.shape
# Out:
# (16, 5)

# %%
duplicate_all
# Out:
#                        id                                              title  \
# 135718          0911.2604  Precision Electroweak Measurements and Constra...
# 146842          1001.4548                               On the BICM Capacity
# 147327          1001.5100  On Exponential Sums, Nowton identities and Dic...
# 153050          1003.1370  AKARI's infrared view on nearby stars : Using ...
# 161313          1004.5254  D\'eveloppements asymptotiques combin\'es et p...
# 164220          1005.3192  Associative Geometries. I: Torsors, linear rel...
# 164221          1005.3193  Associative Geometries. II: Involutions, the c...
# 182970          1009.3141  Analysis of semidiscretization of the compress...
# 198425          1012.2367  Precision Electroweak Measurements and Constra...
# 370771          1307.3655         Photoionization Delay in He, Ne, Ar and Kr
# 450090          1408.2065                         Normalized Online Learning
# 568882         1602.03863  Resolving the problem of definite outcomes of ...
# 1397635  astro-ph/9506093                     The environments of z<0.3 QSOs
# 1502719     gr-qc/0402014  Regularization parameters for the self-force o...
# 1520691    hep-ex/9902018  Study of the Photonuclear interaction of muons...
# 1571290    hep-ph/9708268  Two-Body Dirac Equation and Its Wave Function ...
#
#                                                   comments  \
# 135718                                            18 pages
# 146842   Submitted to the IEEE Transactions on Informat...
# 147327                                            18 pages
# 153050   14 pages, 11 figures, accepted for publication...
# 161313   141 pages num\'erot\'ees par paires de 1 \`a 7...
# 164220   v2: new results on relation with lattice theor...
# 164221   V2: terminology changed ("torsor" instead of "...
# 182970                                            31 pages
# 198425                                            18 pages
# 370771   This paper has been withdrawn by the author be...
# 450090   Appears in Proceedings of the Twenty-Ninth Con...
# 568882   superseded by arXiv:2002.11170 "Entanglement a...
# 1397635  uuencoded compressed postscript. The preprint ...
# 1502719                                27 pages, no figure
# 1520691  4 pages, 2 figures, to be published in Proc. o...
# 1571290                                    LaTeX, 12 pages
#
#                                                journal-ref       categories
# 135718                                                 NaN           hep-ex
# 146842   IEEE Trans. Inform. Theory, vol. 57, no. 10, p...    cs.IT math.IT
# 147327                                                 NaN    cs.IT math.IT
# 153050                                                 NaN      astro-ph.SR
# 161313                                                 NaN          math.DS
# 164220                                                 NaN          math.RA
# 164221                                                 NaN          math.RA
# 182970                                                 NaN          math.CA
# 198425                                                 NaN           hep-ex
# 370771                                                 NaN  physics.atom-ph
# 450090                                                 NaN    cs.LG stat.ML
# 568882                                                 NaN         quant-ph
# 1397635                                                NaN         astro-ph
# 1502719                                                NaN            gr-qc
# 1520691                                                NaN           hep-ex
# 1571290                                                NaN           hep-ph

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1726178 entries, 0 to 1726210
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           object
#  1   title        object
#  2   comments     object
#  3   journal-ref  object
#  4   categories   object
# dtypes: object(5)
# memory usage: 79.0+ MB

# %%
df = df.drop_duplicates('title', keep='first')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1722828 entries, 0 to 1726210
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           object
#  1   title        object
#  2   comments     object
#  3   journal-ref  object
#  4   categories   object
# dtypes: object(5)
# memory usage: 78.9+ MB

# %%
#set sns styles
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")

# %%
#create copy dataset to calculate the length of the 5 fields for plotting
data_lengths = df[['id', 'title', 'comments', 'journal-ref', 'categories']].copy()
data_lengths.head()
# Out:
#           id                                              title  \
# 0  0704.0001  Calculation of prompt diphoton production cros...
# 1  0704.0002           Sparsity-certifying Graph Decompositions
# 2  0704.0003  The evolution of the Earth-Moon system based o...
# 3  0704.0004  A determinant of Stirling cycle numbers counts...
# 4  0704.0006  Bosonic characters of atomic Cooper pairs acro...
#
#                                   comments               journal-ref  \
# 0  37 pages, 15 figures; published version  Phys.Rev.D76:013009,2007
# 1    To appear in Graphs and Combinatorics                       NaN
# 2                      23 pages, 3 figures                       NaN
# 3                                 11 pages                       NaN
# 4      6 pages, 4 figures, accepted by PRA                       NaN
#
#           categories
# 0             hep-ph
# 1      math.CO cs.CG
# 2     physics.gen-ph
# 3            math.CO
# 4  cond-mat.mes-hall

# %%
#Calculate the length of the fields
data_lengths['id_len'] = data_lengths['id'].str.len()
data_lengths['title_len'] = data_lengths['title'].str.len()
data_lengths['comments_len'] = data_lengths['comments'].str.len()
data_lengths['journal-ref_len'] = data_lengths['journal-ref'].str.len()
data_lengths['categories_len'] = data_lengths['categories'].str.len()
data_lengths.head()
# Out:
#           id                                              title  \
# 0  0704.0001  Calculation of prompt diphoton production cros...
# 1  0704.0002           Sparsity-certifying Graph Decompositions
# 2  0704.0003  The evolution of the Earth-Moon system based o...
# 3  0704.0004  A determinant of Stirling cycle numbers counts...
# 4  0704.0006  Bosonic characters of atomic Cooper pairs acro...
#
#                                   comments               journal-ref  \
# 0  37 pages, 15 figures; published version  Phys.Rev.D76:013009,2007
# 1    To appear in Graphs and Combinatorics                       NaN
# 2                      23 pages, 3 figures                       NaN
# 3                                 11 pages                       NaN
# 4      6 pages, 4 figures, accepted by PRA                       NaN
#
#           categories  id_len  title_len  comments_len  journal-ref_len  \
# 0             hep-ph       9         87            39             24.0
# 1      math.CO cs.CG       9         40            37              NaN
# 2     physics.gen-ph       9         83            19              NaN
# 3            math.CO       9         89             8              NaN
# 4  cond-mat.mes-hall       9         58            35              NaN
#
#    categories_len
# 0               6
# 1              13
# 2              14
# 3               7
# 4              17

# %%
#Plot histogram of id length
sns.histplot(data=data_lengths, y='id_len', legend=False)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='id_len'>

# %%
#countplot id_len
sns.countplot(x ='id_len', hue ='id_len', data = data_lengths)
# Out:
# <AxesSubplot:xlabel='id_len', ylabel='count'>

# %%
#Plot histogram of id length
sns.histplot(data=data_lengths, y='title_len', legend=False)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='title_len'>

# %%
sns.scatterplot(x='comments_len', y='journal-ref_len', data=data_lengths)
# Out:
# <AxesSubplot:xlabel='comments_len', ylabel='journal-ref_len'>

# %%
g=sns.scatterplot(data=data_lengths, x='comments_len', y='journal-ref_len', hue='id_len')
g.figure.set_size_inches(18.5, 10.5)

# %%
sns.lmplot(data=data_lengths, x ='journal-ref_len', y ='categories_len')

# %%
sns.lmplot(data=data_lengths, x ='categories_len', y ='journal-ref_len')

# %%
#Drop rows with NaN in journal-ref
data_lengths = data_lengths[data_lengths['journal-ref'].notna()]

# %%
g=sns.lmplot(data=data_lengths, x ='categories_len', y ='journal-ref_len', hue='id_len')
g.figure.set_size_inches(18.5, 10.5)

# %%
sns.lmplot(data=data_lengths, x ='categories_len', y ='journal-ref_len')

# %%
g=sns.regplot(data=data_lengths, x ='categories_len', y ='journal-ref_len')
g.figure.set_size_inches(18.5, 10.5)

# %%
#create new dataset to calculate most common word in title
title = df[['id', 'title', 'journal-ref']].copy()
title.head()
# Out:
#           id                                              title  \
# 0  0704.0001  Calculation of prompt diphoton production cros...
# 1  0704.0002           Sparsity-certifying Graph Decompositions
# 2  0704.0003  The evolution of the Earth-Moon system based o...
# 3  0704.0004  A determinant of Stirling cycle numbers counts...
# 4  0704.0006  Bosonic characters of atomic Cooper pairs acro...
#
#                 journal-ref
# 0  Phys.Rev.D76:013009,2007
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
#transform data so that all text in title is in lowercase
title['title'] = title['title'].astype(str).str.lower()
title.head(3)
# Out:
#           id                                              title  \
# 0  0704.0001  calculation of prompt diphoton production cros...
# 1  0704.0002           sparsity-certifying graph decompositions
# 2  0704.0003  the evolution of the earth-moon system based o...
#
#                 journal-ref
# 0  Phys.Rev.D76:013009,2007
# 1                       NaN
# 2                       NaN

# %%
#Tokenize to split individual words
from nltk.tokenize import RegexpTokenizer

regexp = RegexpTokenizer('\w+')

title['text_token']=title['title'].apply(regexp.tokenize)
title.head(3)
# Out:
#           id                                              title  \
# 0  0704.0001  calculation of prompt diphoton production cros...
# 1  0704.0002           sparsity-certifying graph decompositions
# 2  0704.0003  the evolution of the earth-moon system based o...
#
#                 journal-ref                                         text_token
# 0  Phys.Rev.D76:013009,2007  [calculation, of, prompt, diphoton, production...
# 1                       NaN      [sparsity, certifying, graph, decompositions]
# 2                       NaN  [the, evolution, of, the, earth, moon, system,...

# %%
#Create list English stopwords
stopwords = nltk.corpus.stopwords.words("english")
title['text_token'] = title['text_token'].apply(lambda x: [item for item in x if item not in stopwords])
title.head(3)
# Out:
#           id                                              title  \
# 0  0704.0001  calculation of prompt diphoton production cros...
# 1  0704.0002           sparsity-certifying graph decompositions
# 2  0704.0003  the evolution of the earth-moon system based o...
#
#                 journal-ref                                         text_token
# 0  Phys.Rev.D76:013009,2007  [calculation, prompt, diphoton, production, cr...
# 1                       NaN      [sparsity, certifying, graph, decompositions]
# 2                       NaN  [evolution, earth, moon, system, based, dark, ...

# %%
#Change the format of text_token to strings and keep only words which are longer than 3 letters
title['text_string'] = title['text_token'].apply(lambda x: ' '.join([item for item in x if len(item)>3]))
title.head()
# Out:
#           id                                              title  \
# 0  0704.0001  calculation of prompt diphoton production cros...
# 1  0704.0002           sparsity-certifying graph decompositions
# 2  0704.0003  the evolution of the earth-moon system based o...
# 3  0704.0004  a determinant of stirling cycle numbers counts...
# 4  0704.0006  bosonic characters of atomic cooper pairs acro...
#
#                 journal-ref  \
# 0  Phys.Rev.D76:013009,2007
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                                           text_token  \
# 0  [calculation, prompt, diphoton, production, cr...
# 1      [sparsity, certifying, graph, decompositions]
# 2  [evolution, earth, moon, system, based, dark, ...
# 3  [determinant, stirling, cycle, numbers, counts...
# 4  [bosonic, characters, atomic, cooper, pairs, a...
#
#                                          text_string
# 0  calculation prompt diphoton production cross s...
# 1           sparsity certifying graph decompositions
# 2  evolution earth moon system based dark matter ...
# 3  determinant stirling cycle numbers counts unla...
# 4  bosonic characters atomic cooper pairs across ...

# %%
#Create a list of all words
all_words = ' '.join([word for word in title['text_string']])
#Tokenize all_words
tokenized_words = nltk.tokenize.word_tokenize(all_words)
#Freq distribution all words
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_words)
fdist
# Out:
# FreqDist({'quantum': 101663, 'model': 78349, 'theory': 55501, 'using': 50786, 'field': 47952, 'based': 47631, 'systems': 46953, 'learning': 46112, 'spin': 43343, 'models': 40674, ...})

# %%
#Add to table dropping words that only appear 100 times or more
title['text_string_fdist'] = title['text_token'].apply(lambda x: ' '.join([item for item in x if fdist[item] >= 100 ]))
title.head()
# Out:
#           id                                              title  \
# 0  0704.0001  calculation of prompt diphoton production cros...
# 1  0704.0002           sparsity-certifying graph decompositions
# 2  0704.0003  the evolution of the earth-moon system based o...
# 3  0704.0004  a determinant of stirling cycle numbers counts...
# 4  0704.0006  bosonic characters of atomic cooper pairs acro...
#
#                 journal-ref  \
# 0  Phys.Rev.D76:013009,2007
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                                           text_token  \
# 0  [calculation, prompt, diphoton, production, cr...
# 1      [sparsity, certifying, graph, decompositions]
# 2  [evolution, earth, moon, system, based, dark, ...
# 3  [determinant, stirling, cycle, numbers, counts...
# 4  [bosonic, characters, atomic, cooper, pairs, a...
#
#                                          text_string  \
# 0  calculation prompt diphoton production cross s...
# 1           sparsity certifying graph decompositions
# 2  evolution earth moon system based dark matter ...
# 3  determinant stirling cycle numbers counts unla...
# 4  bosonic characters atomic cooper pairs across ...
#
#                                    text_string_fdist
# 0  calculation prompt diphoton production cross s...
# 1           sparsity certifying graph decompositions
# 2  evolution earth moon system based dark matter ...
# 3  determinant stirling cycle numbers counts unla...
# 4  bosonic characters atomic cooper pairs across ...

# %%
#Lemmatization to identify similar words
from nltk.stem import WordNetLemmatizer

wordnet_lem = WordNetLemmatizer()
title['text_string_lem'] = title['text_string_fdist'].apply(wordnet_lem.lemmatize)
#There may be no words to lemmatize
title['is_equal']= (title['text_string_fdist']==title['text_string_lem'])
# show level count
title.is_equal.value_counts()
# Out:
# True     1719753
# False       3075
# Name: is_equal, dtype: int64

# %%
#Frequency Distribution
all_words_lem = ' '.join([word for word in title['text_string_lem']])
words = nltk.word_tokenize(all_words_lem)
fd = FreqDist(words)
#Top 10 
fd.most_common(10)
# Out:
# [('quantum', 101664),
#  ('model', 78372),
#  ('theory', 55512),
#  ('using', 50786),
#  ('field', 47962),
#  ('based', 47631),
#  ('systems', 46930),
#  ('learning', 46112),
#  ('spin', 43343),
#  ('models', 40651)]

# %%
#plot graph top 20 most common words
top_20 = fd.most_common(20)
fdist = pd.Series(dict(top_20))
sns.barplot(y=fdist.index, x=fdist.values)
# Out:
# <AxesSubplot:>

# %%
#Create data frame for titles that include quantum
quan = df[df['title'].str.contains('quantum|Quantum')]
quan.head()
# Out:
#            id                                              title  \
# 5   0704.0007  Polymer Quantum Mechanics and its Continuum Limit
# 28  0704.0034  Origin of adaptive mutants: a quantum measurem...
# 35  0704.0041  Quantum Group of Isometries in Classical and N...
# 36  0704.0042  General System theory, Like-Quantum Semantics ...
# 46  0704.0052  Quantum Field Theory on Curved Backgrounds. II...
#
#                                              comments  \
# 5   16 pages, no figures. Typos corrected to match...
# 28                                            5 pages
# 35  improvements: (i) more general approach throug...
# 36                                 12 pages,3 figures
# 46                                 18 pages, 1 figure
#
#                  journal-ref                  categories
# 5   Phys.Rev.D76:044016,2007                       gr-qc
# 28                       NaN  q-bio.PE q-bio.CB quant-ph
# 35                       NaN     math.QA math-ph math.MP
# 36                       NaN     physics.gen-ph quant-ph
# 46                       NaN                      hep-th

# %%
#Find the 10 most common journal refs in model
quan['journal-ref'].value_counts().nlargest(10)
# Out:
# Commun. Math. Phys. (2022)                                                                                                                   4
# In "Quantum Error Correction", edited by Daniel A. Lidar and Todd\n  A. Brun, (Cambridge University Press, 2013)                             3
# Prog Theor Exp Phys (2018)                                                                                                                   3
# in: A. V. Stoyanovsky, Introduction to the mathematical principles\n  of quantum field theory, Editorial URSS, Moscow, 2007 (in Russian).    3
# Prog Theor Exp Phys (2020)                                                                                                                   3
# Phys. Rev. A 93, 052105 (2016)                                                                                                               3
# Nature Physics (2018)                                                                                                                        3
# 2021 IEEE/ACM Second International Workshop on Quantum Computing\n  Software (QCS)                                                           2
# Phys. Rev. A 100, 033820 (2019)                                                                                                              2
# Nat. Phys. (2023)                                                                                                                            2
# Name: journal-ref, dtype: int64

# %%
#Create data frame for titles that include model and find top 10 references
model = df[df['title'].str.contains('model|Model')]
model['journal-ref'].value_counts().nlargest(10)
# Out:
# Dans Design, Automation and Test in Europe - DATE'05, Munich :\n  Allemagne (2005)                                               18
# Prog Theor Exp Phys (2020)                                                                                                       12
# Prog Theor Exp Phys (2022)                                                                                                       11
# Prog Theor Exp Phys (2018)                                                                                                       10
# Prog Theor Exp Phys (2019)                                                                                                        9
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2008, Nice : France (2008)                      9
# Prog Theor Exp Phys (2021)                                                                                                        8
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2007, Stresa, lago Maggiore : Italie (2007)     8
# Dans Proceedings of 12th International Workshop on Thermal\n  investigations of ICs - THERMINIC 2006, Nice : France (2006)        6
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2006, Stresa, Lago Maggiore : Italie (2006)     5
# Name: journal-ref, dtype: int64

# %%
#Create data frame for titles that include theory and find top 10 references
theory = df[df['title'].str.contains('theory|Theory')]
theory['journal-ref'].value_counts().nlargest(10)
# Out:
# Prog Theor Exp Phys (2018)                                                                                                                   7
# Prog Theor Exp Phys (2022)                                                                                                                   6
# Prog Theor Exp Phys (2019)                                                                                                                   4
# Prog Theor Exp Phys (2017)                                                                                                                   4
# in: A. V. Stoyanovsky, Introduction to the mathematical principles\n  of quantum field theory, Editorial URSS, Moscow, 2007 (in Russian).    3
# Prog Theor Exp Phys (2020)                                                                                                                   3
# Nucl.Phys.B438:182-210,1995; Addendum-ibid.B449:146-148,1995                                                                                 2
# Ether space-time and cosmology, Michael C. Duffy and Joseph Levy\n  Editors, March 2008                                                      2
# Physical Review B 66, 014412 (2002)                                                                                                          2
# Mon.Not.Roy.Astron.Soc. 290 (1997) 439                                                                                                       2
# Name: journal-ref, dtype: int64

# %%
#Create data frame for titles that include using and find top 10 references
using = df[df['title'].str.contains('using|Using')]
using['journal-ref'].value_counts().nlargest(10)
# Out:
# Dans Design, Automation and Test in Europe - DATE'05, Munich :\n  Allemagne (2005)                                               14
# IJCSI, Volume 7, Issue 2, March 2010                                                                                              6
# Journal of Computing, Vol. 2, No. 6, June 2010, NY, USA, ISSN\n  2151-9617                                                        6
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2006, Stresa, Lago Maggiore : Italie (2006)     6
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2008, Nice : France (2008)                      6
# International Journal of Computer Science and Information\n  Security, IJCSIS, Vol. 4, No. 1 & 2, August 2009, USA                5
# 2019                                                                                                                              4
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2007, Stresa, lago Maggiore : Italie (2007)     4
# IJCSIS June 2009 Issue, Vol. 2, No. 1                                                                                             4
# Dans Proceedings of 12th International Workshop on Thermal\n  investigations of ICs - THERMINIC 2006, Nice : France (2006)        4
# Name: journal-ref, dtype: int64

# %%
#Create data frame for titles that include field and find top 10 references
field = df[df['title'].str.contains('field|Field')]
field['journal-ref'].value_counts().nlargest(10)
# Out:
# Prog Theor Exp Phys (2018)                                                                                                                   7
# Prog Theor Exp Phys (2019)                                                                                                                   6
# in: A. V. Stoyanovsky, Introduction to the mathematical principles\n  of quantum field theory, Editorial URSS, Moscow, 2007 (in Russian).    4
# Prog Theor Exp Phys (2020)                                                                                                                   4
# Prog Theor Exp Phys (2017)                                                                                                                   4
# Phys. Rev. B 83, 144414 (2011)                                                                                                               2
# Int.J.Mod.Phys.D15:2223-2228,2006                                                                                                            2
# Proc. SPIE 11447, Ground-based and Airborne Instrumentation for\n  Astronomy VIII, 2020                                                      2
# Phys. Rev. D 92, 124047 (2015)                                                                                                               2
# Classical and Quantum Gravity, 2021                                                                                                          2
# Name: journal-ref, dtype: int64

# %%
#Create data frame for titles that include based and find top 10 references
based = df[df['title'].str.contains('based|Based')]
based['journal-ref'].value_counts().nlargest(10)
# Out:
# Dans Design, Automation and Test in Europe - DATE'05, Munich :\n  Allemagne (2005)                                               17
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2008, Nice : France (2008)                     12
# Dans Design, Automation and Test in Europe | Designers'Forum -\n  DATE'05, Munich : Allemagne (2005)                              7
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2006, Stresa, Lago Maggiore : Italie (2006)     7
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2007, Stresa, lago Maggiore : Italie (2007)     7
# Journal of Computing, Vol. 2, No. 6, June 2010, NY, USA, ISSN\n  2151-9617                                                        6
# IJCSIS June 2009 Issue, Vol. 2, No. 1                                                                                             5
# IJCSI, Volume 7, Issue 2, March 2010                                                                                              5
# AAAI 2020                                                                                                                         4
# Journal of Computing, Volume 2, Issue 5, May 2010                                                                                 3
# Name: journal-ref, dtype: int64

# %%
#Create data frame for titles that include systems and find top 10 references
systems = df[df['title'].str.contains('systems|Systems')]
systems['journal-ref'].value_counts().nlargest(10)
# Out:
# Dans Design, Automation and Test in Europe - DATE'05, Munich :\n  Allemagne (2005)                                               12
# Dans Design, Automation and Test in Europe | Designers'Forum -\n  DATE'05, Munich : Allemagne (2005)                              6
# Phys.Rev. C65 (2002) 045501                                                                                                       3
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2007, Stresa, lago Maggiore : Italie (2007)     3
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2008, Nice : France (2008)                      3
# SIAM J. Sci. Comput. 36(5): A2248-A2271, 2014                                                                                     2
# IEEE Communications Letters 2021                                                                                                  2
# Phys. Rev. E 100, 012134 (2019)                                                                                                   2
# 58th IEEE Conference on Decision and Control (CDC 2019)                                                                           2
# Astron.Astrophys.321:45,1997                                                                                                      2
# Name: journal-ref, dtype: int64

# %%
#Create data frame for titles that include learning and find top 10 references
learning = df[df['title'].str.contains('learning|Learning')]
learning['journal-ref'].value_counts().nlargest(10)
# Out:
# ICLR 2022                                                                                                    6
# AAAI 2022                                                                                                    6
# ECCV 2022                                                                                                    5
# ICLR 2023                                                                                                    4
# NeurIPS 2021                                                                                                 4
# Transactions on Machine Learning Research, 2022                                                              4
# 2020 42nd Annual International Conference of the IEEE Engineering\n  in Medicine & Biology Society (EMBC)    4
# IEEE Transactions on Pattern Analysis and Machine Intelligence,\n  2022                                      4
# Advances in Neural Information Processing Systems, 2021                                                      3
# NeurIPS 2020                                                                                                 3
# Name: journal-ref, dtype: int64

# %%
#Create data frame for titles that include spin and find top 10 references
spin = df[df['title'].str.contains('spin|Spin')]
spin['journal-ref'].value_counts().nlargest(10)
# Out:
# Prog Theor Exp Phys (2019)                3
# Nature Physics 3, 780 (2007)              2
# Phys. Rev. B 80, 024420 (2009)            2
# J. Math. Anal. Appl. (2020)               2
# Phys. Rev. B 91, 155103 (2015)            2
# Nano Letters (2018)                       2
# Nano Lett., 2009, 9 (12), pp 4204-4208    2
# Phys. Rev. Research 2, 013099 (2020)      2
# Phys. Rev. Lett. 110, 246403 (2013)       2
# Phys. Rev. B 72, 184401 (2005)            2
# Name: journal-ref, dtype: int64

# %%
#Create data frame for titles that include models and find top 10 references
models = df[df['title'].str.contains('models|Models')]
models['journal-ref'].value_counts().nlargest(10)
# Out:
# Prog Theor Exp Phys (2022)                                                                                      6
# ICLR 2023                                                                                                       4
# In Proceedings of the Fifth Workshop on Constraint Based Methods\n  for Bioinformatics (WCB09), 2009, Lisbon    2
# Lett.Math.Phys.84:257-273,2008                                                                                  2
# JHEP 1102 (2011) 038                                                                                            2
# Statistical Papers 2020                                                                                         2
# EMNLP 2018                                                                                                      2
# Phys. Rev. A 97, 052119 (2018)                                                                                  2
# CIKM 2020                                                                                                       2
# Phys. Rev. B 90, 174408 (2014)                                                                                  2
# Name: journal-ref, dtype: int64

# %%
# Redo model search with space after model to compare the resutls with original model search
model2 = df[df['title'].str.contains('model |Model ')]
model2['journal-ref'].value_counts().nlargest(10)
# Out:
# Prog Theor Exp Phys (2020)                                                                                                       6
# Dans Design, Automation and Test in Europe - DATE'05, Munich :\n  Allemagne (2005)                                               6
# Prog Theor Exp Phys (2021)                                                                                                       5
# Prog Theor Exp Phys (2022)                                                                                                       4
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2006, Stresa, Lago Maggiore : Italie (2006)    3
# Prog Theor Exp Phys (2019)                                                                                                       3
# Prog Theor Exp Phys (2018)                                                                                                       3
# Prog Theor Exp Phys (2017)                                                                                                       3
# 2020 International Joint Conference on Neural Networks (IJCNN)                                                                   2
# Transaction on Automatic Control, 2020                                                                                           2
# Name: journal-ref, dtype: int64

# %%
model2['journal-ref'].isnull().sum()
# Out:
# 25591

# %%
quan['journal-ref'].isnull().sum()
# Out:
# 40796

# %%
theory['journal-ref'].isnull().sum()
# Out:
# 27010

# %%
using['journal-ref'].isnull().sum()
# Out:
# 36356

# %%
field['journal-ref'].isnull().sum()
# Out:
# 34341

# %%
based['journal-ref'].isnull().sum()
# Out:
# 35447

# %%
systems['journal-ref'].isnull().sum()
# Out:
# 28999

# %%
learning['journal-ref'].isnull().sum()
# Out:
# 39614

# %%
spin['journal-ref'].isnull().sum()
# Out:
# 18574

# %%
models['journal-ref'].isnull().sum()
# Out:
# 23828
